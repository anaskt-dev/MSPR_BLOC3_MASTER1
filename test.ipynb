# %%
import duckdb

con = duckdb.connect("warehouse.duckdb")

print(con.execute("SHOW TABLES").fetchdf())
print(con.execute("SELECT * FROM dim_commune LIMIT 5").fetchdf())
print(con.execute("SELECT * FROM vw_elections_communes LIMIT 5").fetchdf())

con.close()
# Out:
#                           name
# 0                  dim_commune
# 1              dim_departement
# 2                dim_iris_lyon
# 3                    dim_temps
# 4                fact_diplomes
# 5          fact_election_tour1
# 6          fact_election_tour2
# 7       fact_emploi_pop_active
# 8                fact_logement
# 9                 fact_revenus
# 10               fact_securite
# 11       vw_elections_communes
# 12  vw_indicateurs_territoires
#   codgeo  libelle_commune code_departement
# 0  69001             <NA>               69
# 1  69002             <NA>               69
# 2  69003             <NA>               69
# 3  69004             <NA>               69
# 4  69005             <NA>               69
#   codgeo  libelle_commune libelle_departement  annee  inscrits  votants  \
# 0  69001             <NA>               Rhone   2024       316      256
# 1  69002             <NA>               Rhone   2024       217      159
# ...
